# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0465/AI-LAB/blob/master/npl1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
A="New Delhi: PM Narendra Modi is likely to address the nation again to announce his decision on whether the coronaviruslockdown will end on Tuesday. Before the decision, he will meet with Chief Ministers via video conference today.In a video meeting with leaders of all parties on Wednesday, PM Modi had said by all accounts the lifting of the lockdownis not possible"
"The priority of the government is to save each and every life. The situation in the country is akin to a 'social emergency', it has necessitated tough decisions and we must continue to remain vigilant,said the PM, according to political leaders who participated in the interaction."
B="PM Modi's decision to order the three-week lockdown has helped slow the infection rate, foreign 	ministry additionalsecretary Vikas Swarup has said, even though it has impacted the economy and thousands of poor workers. Millions of people have lost their jobs, largely those who work on daily wages and have fled to their homes in villagesMany states have sought an extension of the 21-day nationwide lockdown announced by PM Modi on March 25, saying they will not be able to handle a surge of COVID-19 cases. Odisha yesterday became the first state to announce a lockdown till the end of this month. PM Modi expressed to have good days after lockdown,"
C="J.P Nadda on Thursday slammed Congress chief Sonia Gandhi's criticism of the lockdown as insensitive and indecent,saying this is not the time for politics when the entire country is fighting the coronavirus. Top Congress leaders on Thursday discussed the situation arising out of the coronavirus outbreak, with party chief Sonia Gandhi criticizing the Centre for unplanned implementation of the lockdown and calling for solidarity in meeting the challenge posed by the pandemic."

# %%
bagOfWordsA = A.split(' ')
bagOfWordsB = B.split(' ')
bagOfWordsC = C.split(' ')

# %%
print(bagOfWordsA) 
print(bagOfWordsB) 
print(bagOfWordsC)
# Out:
# ['New', 'Delhi:', 'PM', 'Narendra', 'Modi', 'is', 'likely', 'to', 'address', 'the', 'nation', 'again', 'to', 'announce', 'his', 'decision', 'on', 'whether', 'the', 'coronaviruslockdown', 'will', 'end', 'on', 'Tuesday.', 'Before', 'the', 'decision,', 'he', 'will', 'meet', 'with', 'Chief', 'Ministers', 'via', 'video', 'conference', 'today.In', 'a', 'video', 'meeting', 'with', 'leaders', 'of', 'all', 'parties', 'on', 'Wednesday,', 'PM', 'Modi', 'had', 'said', 'by', 'all', 'accounts', 'the', 'lifting', 'of', 'the', 'lockdownis', 'not', 'possible']
# ...

# %%
uniqueWords = set(bagOfWordsA).union(set(bagOfWordsB))
uniqueWords
# Out:
# {'\tministry',
#  '21-day',
#  '25,',
#  'Before',
#  'COVID-19',
#  'Chief',
#  'Delhi:',
#  'March',
#  'Millions',
#  'Ministers',
#  'Modi',
#  "Modi's",
#  'Narendra',
#  'New',
#  'Odisha',
#  'PM',
#  'Swarup',
#  'Tuesday.',
#  'Vikas',
#  'Wednesday,',
#  'a',
#  'able',
#  'accounts',
#  'additionalsecretary',
#  'address',
#  'after',
#  'again',
#  'all',
#  'an',
#  'and',
#  'announce',
#  'announced',
#  'be',
#  'became',
#  'by',
#  'cases.',
#  'conference',
#  'coronaviruslockdown',
#  'daily',
#  'days',
#  'decision',
#  'decision,',
#  'economy',
#  'end',
#  'even',
#  'expressed',
#  'extension',
#  'first',
#  'fled',
#  'foreign',
#  'good',
#  'had',
#  'handle',
#  'has',
#  'have',
#  'he',
#  'helped',
#  'his',
#  'homes',
#  'impacted',
#  'in',
#  'infection',
#  'is',
#  'it',
#  'jobs,',
#  'largely',
#  'leaders',
#  'lifting',
#  'likely',
#  'lockdown',
#  'lockdown,',
#  'lockdownis',
#  'lost',
#  'meet',
#  'meeting',
#  'month.',
# ...

# %%
 
uniqueWords=set(uniqueWords).union(set(bagOfWordsC))

# %%
uniqueWords
# Out:
# {'\tministry',
#  '21-day',
#  '25,',
#  'Before',
#  'COVID-19',
#  'Centre',
#  'Chief',
#  'Congress',
#  'Delhi:',
#  'Gandhi',
#  "Gandhi's",
#  'J.P',
#  'March',
#  'Millions',
#  'Ministers',
#  'Modi',
#  "Modi's",
#  'Nadda',
#  'Narendra',
#  'New',
#  'Odisha',
#  'PM',
#  'Sonia',
#  'Swarup',
#  'Thursday',
#  'Top',
#  'Tuesday.',
#  'Vikas',
#  'Wednesday,',
#  'a',
#  'able',
#  'accounts',
#  'additionalsecretary',
#  'address',
#  'after',
#  'again',
#  'all',
#  'an',
#  'and',
#  'announce',
#  'announced',
#  'arising',
#  'as',
#  'be',
#  'became',
#  'by',
#  'calling',
#  'cases.',
#  'challenge',
#  'chief',
#  'conference',
#  'coronavirus',
#  'coronavirus.',
#  'coronaviruslockdown',
#  'country',
#  'criticism',
#  'criticizing',
#  'daily',
#  'days',
#  'decision',
#  'decision,',
#  'discussed',
#  'economy',
#  'end',
#  'entire',
#  'even',
#  'expressed',
#  'extension',
#  'fighting',
#  'first',
#  'fled',
#  'for',
#  'foreign',
#  'good',
# ...

# %%
numOfWordsA = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsA:
    numOfWordsA[word] += 1

numOfWordsB = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsB:
    numOfWordsB[word] += 1
    
numOfWordsC = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsC:
    numOfWordsC[word] += 1

# %%
print(numOfWordsA)

print(numOfWordsB )

print(numOfWordsC )
# Out:
# {'again': 1, 'and': 0, 'when': 0, 'leaders': 1, 'Vikas': 0, 'those': 0, 'daily': 0, 'calling': 0, 'Nadda': 0, 'saying': 0, 'by': 1, 'work': 0, 'days': 0, 'outbreak,': 0, 'unplanned': 0, 'address': 1, 'poor': 0, 'COVID-19': 0, 'entire': 0, 'lockdown,': 0, 'till': 0, 'Modi': 2, 'thousands': 0, 'lost': 0, 'have': 0, 'for': 0, 'out': 0, 'economy': 0, 'coronavirus': 0, 'accounts': 1, 'his': 1, 'challenge': 0, 'they': 0, 'it': 0, 'will': 2, 'helped': 0, 'expressed': 0, 'is': 1, 'Congress': 0, 'announce': 1, 'Narendra': 1, 'homes': 0, 'extension': 0, 'pandemic.': 0, 'country': 0, 'surge': 0, "Modi's": 0, 'whether': 1, 'additionalsecretary': 0, 'decision': 1, "Gandhi's": 0, 'coronaviruslockdown': 1, 'today.In': 1, '\tministry': 0, '21-day': 0, 'Thursday': 0, 'Before': 1, 'discussed': 0, 'Swarup': 0, 'Odisha': 0, 'announced': 0, 'had': 1, 'to': 2, 'of': 2, 'a': 1, 'said': 1, 'video': 2, 'fled': 0, 'not': 1, 'sought': 0, 'Ministers': 1, 'wages': 0, 'decision,': 1, 'situation': 0, 'party': 0, '
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
def computeTF(wordDict, bagOfWords):
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return tfDict

# %%
tfA= computeTF(numOfWordsA, bagOfWordsA)
tfB= computeTF(numOfWordsB, bagOfWordsB)
tfC = computeTF(numOfWordsC, bagOfWordsC)

# %%
print(tfA)
print(tfB)
print(tfC)
# Out:
# {'again': 0.01639344262295082, 'and': 0.0, 'when': 0.0, 'leaders': 0.01639344262295082, 'Vikas': 0.0, 'those': 0.0, 'daily': 0.0, 'calling': 0.0, 'Nadda': 0.0, 'saying': 0.0, 'by': 0.01639344262295082, 'work': 0.0, 'days': 0.0, 'outbreak,': 0.0, 'unplanned': 0.0, 'address': 0.01639344262295082, 'poor': 0.0, 'COVID-19': 0.0, 'entire': 0.0, 'lockdown,': 0.0, 'till': 0.0, 'Modi': 0.03278688524590164, 'thousands': 0.0, 'lost': 0.0, 'have': 0.0, 'for': 0.0, 'out': 0.0, 'economy': 0.0, 'coronavirus': 0.0, 'accounts': 0.01639344262295082, 'his': 0.01639344262295082, 'challenge': 0.0, 'they': 0.0, 'it': 0.0, 'will': 0.03278688524590164, 'helped': 0.0, 'expressed': 0.0, 'is': 0.01639344262295082, 'Congress': 0.0, 'announce': 0.01639344262295082, 'Narendra': 0.01639344262295082, 'homes': 0.0, 'extension': 0.0, 'pandemic.': 0.0, 'country': 0.0, 'surge': 0.0, "Modi's": 0.0, 'whether': 0.01639344262295082, 'additionalsecretary': 0.0, 'decision': 0.01639344262295082, "Gandhi's": 0.0, 'coronavirusl
# ...

# %%
def computeIDF(documents):
    import math
    N = len(documents)
    
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    return idfDict
idfs = computeIDF([numOfWordsA, numOfWordsB,numOfWordsC])
idfs
# Out:
# {'\tministry': 1.0986122886681098,
#  '21-day': 1.0986122886681098,
#  '25,': 1.0986122886681098,
#  'Before': 1.0986122886681098,
#  'COVID-19': 1.0986122886681098,
#  'Centre': 1.0986122886681098,
#  'Chief': 1.0986122886681098,
#  'Congress': 1.0986122886681098,
#  'Delhi:': 1.0986122886681098,
#  'Gandhi': 1.0986122886681098,
#  "Gandhi's": 1.0986122886681098,
#  'J.P': 1.0986122886681098,
#  'March': 1.0986122886681098,
#  'Millions': 1.0986122886681098,
#  'Ministers': 1.0986122886681098,
#  'Modi': 0.4054651081081644,
#  "Modi's": 1.0986122886681098,
#  'Nadda': 1.0986122886681098,
#  'Narendra': 1.0986122886681098,
#  'New': 1.0986122886681098,
#  'Odisha': 1.0986122886681098,
#  'PM': 0.4054651081081644,
#  'Sonia': 1.0986122886681098,
#  'Swarup': 1.0986122886681098,
#  'Thursday': 1.0986122886681098,
#  'Top': 1.0986122886681098,
#  'Tuesday.': 1.0986122886681098,
#  'Vikas': 1.0986122886681098,
#  'Wednesday,': 1.0986122886681098,
#  'a': 0.4054651081081644,
# ...

# %%
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([A,B,C])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)
df
# Out:
#          19        21        25  ...      work   workers  yesterday
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 1  0.080268  0.080268  0.080268  ...  0.080268  0.080268   0.080268
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000   0.000000
#
# [3 rows x 149 columns]

# %%
df["modi"]
# Out:
# 0    0.188327
# 1    0.183138
# 2    0.000000
# Name: modi, dtype: float64
