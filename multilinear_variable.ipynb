# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0465/AI-LAB/blob/master/multilinear_variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd # for handling data in the form of tables
import numpy as np # For handling matrix
from sklearn.model_selection import train_test_split # For spliting the data into train and test
from sklearn.linear_model import LinearRegression # for using the model
from sklearn import metrics
# import matplotlib.pyplot as plt # for plotting

# %%
ipl=pd.read_csv("Iris.csv")
ipl
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
print(ipl.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
.descriplibe()# to study  all stastics summary
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
ipl.describe(include="all")# to study  all stastics summary
# Out:
#                 Id  SepalLengthCm  ...  PetalWidthCm      Species
# count   150.000000     150.000000  ...    150.000000          150
# unique         NaN            NaN  ...           NaN            3
# top            NaN            NaN  ...           NaN  Iris-setosa
# freq           NaN            NaN  ...           NaN           50
# mean     75.500000       5.843333  ...      1.198667          NaN
# std      43.445368       0.828066  ...      0.763161          NaN
# min       1.000000       4.300000  ...      0.100000          NaN
# 25%      38.250000       5.100000  ...      0.300000          NaN
# 50%      75.500000       5.800000  ...      1.300000          NaN
# 75%     112.750000       6.400000  ...      1.800000          NaN
# max     150.000000       7.900000  ...      2.500000          NaN
#
# [11 rows x 6 columns]

# %%
ipl.isna().any() # to find NA's
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
ipl.fillna(0)
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
ipl.fillna(method="pad")#fill na with previous value
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
ipl.fillna(method="bfill")
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#Use interpolate function to fill the missing values which are in data set
ipl.interpolate(method="linear") #‘linear’: ignore the index and treat the values as equally spaced. default
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#Remove rows with NA's in dataset
ipl.dropna() # Drop rows with NA
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#Remove row which contains all NA's

ipl.dropna(how="all") # Drop the rows containing all NA's
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
pd.DataFrame(ipl)
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
ipl.groupby(by='Id').groups
# Out:
# {1: Int64Index([0], dtype='int64'),
#  2: Int64Index([1], dtype='int64'),
#  3: Int64Index([2], dtype='int64'),
#  4: Int64Index([3], dtype='int64'),
#  5: Int64Index([4], dtype='int64'),
#  6: Int64Index([5], dtype='int64'),
#  7: Int64Index([6], dtype='int64'),
#  8: Int64Index([7], dtype='int64'),
#  9: Int64Index([8], dtype='int64'),
#  10: Int64Index([9], dtype='int64'),
#  11: Int64Index([10], dtype='int64'),
#  12: Int64Index([11], dtype='int64'),
#  13: Int64Index([12], dtype='int64'),
#  14: Int64Index([13], dtype='int64'),
#  15: Int64Index([14], dtype='int64'),
#  16: Int64Index([15], dtype='int64'),
#  17: Int64Index([16], dtype='int64'),
#  18: Int64Index([17], dtype='int64'),
#  19: Int64Index([18], dtype='int64'),
#  20: Int64Index([19], dtype='int64'),
#  21: Int64Index([20], dtype='int64'),
#  22: Int64Index([21], dtype='int64'),
#  23: Int64Index([22], dtype='int64'),
#  24: Int64Index([23], dtype='int64'),
#  25: Int64Index([24], dtype='int64'),
# ...

# %%
X = ipl[['Id','SepalWidthCm','PetalLengthCm','PetalWidthCm','SepalLengthCm']].values

y= ipl['SepalLengthCm'].values

# %%
ipl.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1, random_state=123)

# %%
# Now apply linear regression model on training dataset
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# to find the intercept of our model we use  intercept_
print("intercept=",model.intercept_)
# Out:
# intercept= 1.9018991293680751

# %%
# To find  slope of our model we use coef_
print("slope=",model.coef_)
# Out:
# slope= [-0.00180965  0.64353959  0.71626358 -0.48422383]

# %%
#a=predict interpercentage
a=model.predict(X_test) 
a
# Out:
# array([6.16199925])

# %%
# b=actual prediction
b=pd.DataFrame({'predicted':a.flatten(), 'Actual':y_test.flatten()})
b.head()
# Out:
#    predicted  Actual
# 0   6.161999     6.3

# %%
metrics.mean_absolute_error(y_test,a)
# Out:
# 0.13800075235051867

# %%
}

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
n=ipl["PetalLengthCm"]
n.plot(kind="hist")
plt.show()

# %%
m=ipl['SepalLengthCm']
n=ipl['PetalLengthCm']

plt.scatter(m,n,color="red",marker='^')

# %%
import seaborn as sns
corrMatrix=ipl.corr()
sns.heatmap(corrMatrix,annot=True )

# %%
sns.set(style="dark")
sns.boxplot(k=ipl['SepalLengthCm'])

# %%
ipl.boxplot(by="SepalLengthCm",column="SepalWidthCm",grid = True)

# %%
sns.pairplot(data=ipl,hue="Species")

# %%
sns.relplot(x="SepalLengthCm", y="SepalWidthCm", col="Species",
            hue="Species", style="Species", size="PetalWidthCm",
            data=ipl)
            
# The function relplot() is named that way because it is designed to visualize many different statistical relationships.

# %%
sns.relplot(x="SepalLengthCm",y="SepalWidthCm",hue="Species",style="Species", kind="line",col="Species",data=ipl)

# %%
#Statistical estimation in seaborn goes beyond descriptive statisitics. For example, it is also possible to enhance a scatterplot to include a linear regression model (and its uncertainty) using lmplot():


sns.lmplot(x="SepalLengthCm", y="SepalWidthCm", col="Species", hue="Species",
           data=ipl);

# %% [markdown]
# Categorical scatterplots:
#
# stripplot() (with kind="strip"; the default)
#
# swarmplot() (with kind="swarm")
#
# Categorical distribution plots:
#
# boxplot() (with kind="box")
#
# violinplot() (with kind="violin")
#
# boxenplot() (with kind="boxen")
#
# Categorical estimate plots:
#
# pointplot() (with kind="point")
#
# barplot() (with kind="bar")
#
# countplot() (with kind="count")

# %%
sns.catplot(x="SepalLengthCm", y="PetalLengthCm",data=ipl,kind="swarm",hue="Species")

# %%
sns.jointplot(x="PetalLengthCm",y="SepalWidthCm",data=ipl,color="green")

# %%
import matplotlib.pyplot as plt
m=ipl['Species']
n=ipl['PetalLengthCm']
plt.bar(m,n,color="blue")
#plt.xlabel("species")
#plt.ylabel("petal length")
#plt.title("species petal length")
#plt.show()
# Out:
# <BarContainer object of 150 artists>

# %%
m=ipl['Species']
n=ipl['PetalWidthCm']
plt.bar(m,n,color="red")
plt.xlabel("species")
plt.ylabel("petal width")
plt.title("species petal length")
plt.show()
