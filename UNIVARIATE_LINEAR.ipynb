# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0465/python-baaic/blob/master/UNIVARIATE_LINEAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # for handling data in the form of tables
import numpy as np # For handling matrix
from sklearn.model_selection import train_test_split # For spliting the data into train and test
from sklearn.linear_model import LinearRegression # for using the model
from sklearn import metrics
# import matplotlib.pyplot as plt # for plotting

# %%
ipl=pd.read_csv("students_placement_data.csv")
ipl
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
ipl.describe()# to study  all stastics summry
# Out:
#           Roll No  SSC Percentage  ...  B.Tech_percentage    Backlogs
# count  117.000000      117.000000  ...         117.000000  117.000000
# mean    59.000000       80.324359  ...          62.943419    4.111111
# std     33.919021        8.879266  ...          12.064306    6.335148
# min      1.000000       47.800000  ...          31.200000    0.000000
# 25%     30.000000       76.000000  ...          54.180000    0.000000
# 50%     59.000000       82.330000  ...          64.360000    0.000000
# 75%     88.000000       87.000000  ...          72.570000    7.000000
# max    117.000000       93.660000  ...          88.100000   25.000000
#
# [8 rows x 5 columns]

# %%
ipl.describe(include="all")# to study  all stastics summary
# Out:
#            Roll No Gender  ... registered_for_ Placement_Training  placement status
# count   117.000000    117  ...                                117               117
# unique         NaN      2  ...                                  2                 2
# top            NaN      M  ...                                yes        Not placed
# freq           NaN     68  ...                                 67                78
# mean     59.000000    NaN  ...                                NaN               NaN
# std      33.919021    NaN  ...                                NaN               NaN
# min       1.000000    NaN  ...                                NaN               NaN
# 25%      30.000000    NaN  ...                                NaN               NaN
# 50%      59.000000    NaN  ...                                NaN               NaN
# 75%      88.000000    NaN  ...                                NaN               NaN
# ...

# %%
ipl
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
ipl.plot(x='SSC Percentage',y='inter_Diploma_percentage',style='*')# to how they are corelated

# %%
#converting a  series into numpy array
x=ipl['SSC Percentage'].values.reshape(-1,1)
x
y=ipl['inter_Diploma_percentage'].values.reshape(-1,1)
y
# Out:
# array([[65.3 ],
#        [92.4 ],
#        [68.  ],
#        [70.4 ],
#        [65.5 ],
#        [68.  ],
#        [56.5 ],
#        [79.3 ],
#        [89.6 ],
#        [75.5 ],
#        [76.3 ],
#        [66.  ],
#        [60.3 ],
#        [88.7 ],
#        [52.2 ],
#        [86.  ],
#        [85.  ],
#        [95.1 ],
#        [86.3 ],
#        [93.6 ],
#        [90.3 ],
#        [83.9 ],
#        [83.  ],
#        [90.4 ],
#        [87.2 ],
#        [78.3 ],
#        [81.  ],
#        [65.3 ],
#        [67.1 ],
#        [88.1 ],
#        [96.5 ],
#        [77.7 ],
#        [88.9 ],
#        [80.1 ],
#        [78.4 ],
#        [90.  ],
#        [91.4 ],
#        [94.3 ],
#        [76.8 ],
#        [88.8 ],
#        [91.4 ],
#        [61.2 ],
#        [67.5 ],
#        [92.5 ],
#        [83.7 ],
#        [84.4 ],
#        [76.9 ],
#        [89.1 ],
#        [77.2 ],
#        [93.8 ],
#        [92.2 ],
#        [79.  ],
#        [73.4 ],
#        [84.5 ],
#        [83.6 ],
# ...

# %%
 #Now divide the data into train and test. Here we are keeping 40% as our test set
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.4)
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
# Out:
# [[66.16]
#  [87.33]
#  [79.  ]
#  [81.83]
#  [63.66]
#  [68.16]
#  [81.1 ]
#  [82.3 ]
#  [86.66]
#  [83.5 ]
#  [88.3 ]
#  [85.5 ]
#  [87.5 ]
#  [85.5 ]
#  [74.  ]
#  [83.16]
#  [83.66]
#  [82.9 ]
#  [77.33]
#  [86.6 ]
#  [74.  ]
#  [90.3 ]
#  [83.83]
#  [85.33]
#  [76.83]
#  [92.33]
#  [87.  ]
#  [90.33]
#  [87.33]
#  [72.17]
#  [77.16]
#  [83.5 ]
#  [78.  ]
#  [89.33]
#  [81.83]
#  [89.  ]
#  [85.83]
#  [82.  ]
#  [85.  ]
#  [82.  ]
#  [75.33]
#  [91.  ]
#  [75.5 ]
#  [83.  ]
#  [81.3 ]
#  [81.1 ]
#  [71.  ]
#  [85.  ]
#  [87.1 ]
#  [87.33]
#  [91.  ]
#  [72.  ]
#  [74.16]
#  [50.66]
#  [81.  ]
#  [82.66]
#  [80.  ]
#  [89.  ]
#  [74.5 ]
#  [67.  ]
#  [79.33]
#  [79.  ]
#  [82.83]
#  [92.66]
#  [88.1 ]
#  [87.33]
#  [88.16]
#  [65.3 ]
#  [80.66]
#  [87.83]]
# [[79.83]
#  [63.1 ]
#  [88.  ]
#  [70.  ]
#  [64.3 ]
#  [74.5 ]
#  [84.84]
#  [82.33]
#  [60.83]
#  [84.83]
#  [67.  ]
#  [62.  ]
#  [90.66]
#  [86.16]
#  [87.42]
#  [87.3 ]
#  [72.  ]
#  [83.5 ]
#  [85.33]
#  [83.  ]
# ...

# %%
# Now apply linear regression model on training dataset
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# to find the intercept of our model we use  intercept_
print("intercept=",model.intercept_)
# Out:
# intercept= [17.51113192]

# %%
# To find  slope of our model we use coef_
print("slope=",model.coef_)
# Out:
# slope= [[0.79139515]]

# %%
#a=predict interpercentage
a=model.predict(X_test) 
a
# Out:
# array([[80.6882064 ],
#        [67.44816561],
#        [87.15390474],
#        [72.90879212],
#        [68.39783979],
#        [76.47007027],
#        [84.65309608],
#        [82.66669426],
#        [65.65169863],
#        [84.64518213],
#        [70.53460668],
#        [66.57763095],
#        [89.25901583],
#        [85.69773767],
#        [86.69489555],
#        [86.59992814],
#        [74.49158241],
#        [83.59262658],
#        [85.0408797 ],
#        [83.19692901],
#        [85.57111445],
#        [91.63320126],
#        [74.88727998],
#        [55.33981988],
#        [68.16042124],
#        [85.57111445],
#        [83.71924981],
#        [87.28052796],
#        [89.1323926 ],
#        [80.74360406],
#        [77.65716299],
#        [74.49158241],
#        [79.71479037],
#        [61.56018573],
#        [81.87529912],
#        [82.64295241],
#        [78.84425571],
#        [87.94529988],
#        [80.03134843],
#        [85.57111445],
#        [73.70018726],
# ...

# %%
# b=actual prediction
b=pd.DataFrame({'predicted':a.flatten(), 'Actual':Y_test.flatten()})
b
# Out:
#     predicted  Actual
# 0   80.688206   64.20
# 1   67.448166   52.20
# 2   87.153905   67.90
# 3   72.908792   81.00
# 4   68.397840   67.10
# 5   76.470070   78.30
# 6   84.653096   91.60
# 7   82.666694   76.30
# 8   65.651699   80.20
# 9   84.645182   79.30
# 10  70.534607   68.00
# 11  66.577631   70.91
# 12  89.259016   94.70
# 13  85.697738   87.20
# 14  86.694896   92.20
# 15  86.599928   65.30
# 16  74.491582   81.00
# 17  83.592627   89.90
# 18  85.040880   93.80
# 19  83.196929   83.00
# 20  85.571114   91.90
# 21  91.633201   95.10
# 22  74.887280   67.80
# 23  55.339820   52.40
# 24  68.160421   56.70
# 25  85.571114   92.50
# 26  83.719250   90.40
# 27  87.280528   91.40
# 28  89.132393   90.40
# 29  80.743604   75.50
# 30  77.657163   80.10
# 31  74.491582   88.10
# 32  79.714790   87.80
# 33  61.560186   65.30
# 34  81.875299   60.30
# 35  82.642952   83.70
# 36  78.844256   83.90
# 37  87.945300   92.40
# 38  80.031348   88.90
# 39  85.571114   94.20
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_test,a)

# %%
print('R2 error:',metrics.r2_score(Y_test, a))
# Out:
# R2 error: 0.43075779457313446
